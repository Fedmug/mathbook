# %% [markdown]
# # Who is this guy?

# %% [markdown]
# ## Sergei Lytkin
#
# `````{grid}
# :gutter: 2
#
# ````{grid-item}
# ```{figure} ./me.jpg
# :align: center
# :height: 300px
# ```
# ````
# ````{grid-item}
#
# **Education & experience**
#
# * PhD in real analysis
# * $8$ years of teaching calculus in MSU
# * master's degree in computer science (YSDA)
# * currently teaching ML&DL in KBTU
# ````
# `````

# %% [markdown]
# ## Moscow State University

# %% [markdown]
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/a/a0/Moscow_State_University_crop.jpg
# :align: center
# ```

# %% [markdown]
# Associate professor at the Department of Mechanics and Mathematics
#
# * teaching calulus (single-variable, multivariate, advanced)
# * solved thousands of calculus problems from Demidovich
# * edited dozens of pages and created hundreds of problems for VOS (new textbook)
# * checked high school olympiad works

# %% [markdown]
# `````{grid}
# :gutter: 2
#
# ````{grid-item}
# ```{figure} https://studizba.com/uploads/files_att/2022-10/1667205866_1667205845818.png
# :align: center
# :height: 200px
# ```
# ````
# ````{grid-item}
# ```{figure} https://m.media-amazon.com/images/I/81aOYKBcacL._AC_UF1000,1000_QL80_.jpg
# :align: center
# :height: 200px
# ```
# ````
#
# ````{grid-item}
# ```{figure} https://cc01.twirpx.net/0263/0263934.jpg?t=20101009122127
# :align: center
# :height: 200px
# ```
# ````
# ````{grid-item}
# ```{figure} https://avatars.mds.yandex.net/get-mpic/4012413/img_id5729007450741619334.png/orig
# :align: center
# :height: 200px
# ```
# ````
# `````

# %% [markdown]
# ```{figure} https://assets.turbologo.ru/blog/ru/2020/02/18162740/Yandex-logo.png
# :align: center
# ```

# %% [markdown]
# ## Yandex.Practicum
#
# Author, methodist and math editor
#
# * math for kids (6th grade)
# * math for DS&ML (combinatorics)

# %% [markdown]
# ## ML Handbook
#
# [Online handbook](https://education.yandex.ru/handbook/ml) on machine learning (in Russian)
#
# * matrix calculus
# * probability and statistics
# * linear algebra

# %% [markdown]
# ## Jupyter Book
#
# * [e-book](https://fedmug.github.io/e_book/euler.html)
# * [ML Book](https://fedmug.github.io/kbtu-ml-book/mlp/MLP_notebook.html)

# %% [markdown]
# <!--
# <img src="https://images.fineartamerica.com/images/artworkimages/mediumlarge/3/al-capone-andrzej-szczerski.jpg" style="width: 300px; float:left; margin: 20px">
#
# You can get much further with a kind ***math*** word and a ~gun~ ***computer*** than you can with a kind ***math*** word alone
#
# ## The main threat
#
# <img src="https://vad.studio/wp-content/uploads/2023/04/chatgpt.jpeg" style="width: 600px">
#
# If you can't beat them, join them
# -->
